# %%
from urllib import request  # urllib.requestモジュールをインポート
from bs4 import BeautifulSoup  # BeautifulSoupクラスをインポート

url = "https://k-tai.watch.impress.co.jp/category/tech/5g/"
response = request.urlopen(url)
soup = BeautifulSoup(response)
response.close()
#soup

## soup と実行すると、ソースコードを吐き出してくれる。
## そこから、必要な要素を考える。
links = soup.find_all("div",class_="body")
for li in links:
    #print(li)
    l = li.find("a")
    if l != None: #liに実態があれば
        url = l.get("href")
        title = li.text.replace( '\n' , '' )#何故か改行が入ってしまってる場合がある。
        print(title)
        print(url)
# Out:
# MVNOの中の人に聞く「ここがイチオシ！」～「BIGLOBE」＆「donedone」編1月4日 11:00
# https://k-tai.watch.impress.co.jp/docs/sim/1377220.html
# 「PayPay」「楽天ペイ」「au PAY」「d払い」1月のキャッシュレス還元まとめ2022年1月からの還元情報をチェック1月4日 06:00
# https://k-tai.watch.impress.co.jp/docs/news/1377878.html
# グーグル、2021年にリリースした既存サービスへの12の機能追加を紹介1月4日 06:00
# https://k-tai.watch.impress.co.jp/docs/news/1377566.html
# 「Fire TV Stick 4K Max」が4980円に、Amazon 初売り1月3日 12:04
# https://k-tai.watch.impress.co.jp/docs/news/1378132.html
# 「iPhone XS」「razr 5G」「Mi 11 Lite 5G」などSIMフリースマホも「Amazonの初売り」に1月3日 11:54
# https://k-tai.watch.impress.co.jp/docs/news/1378130.html
# 「Xperia PRO-I」1.0型イメージセンサー搭載の狙い、そしてPROシリーズがもたらす価値とは――開発者たちに訊く
# /docs/interview/1368457.html
# 楽天モバイル矢澤副社長に聞く、2021年秋のローミング切り替えとこれからのエリア構築
# /docs/interview/1355425.html
# お手頃価格の「iPhone SE（第2世代）」は買い？　待ち？　それとも？
# /docs/column/mobile_catchup/1250980.html
# 「iPhone 13/mini/Pro/Pro Max」はどこが違う？　大きさ・デザイン、カメラを細かくチェックしてみた
# /docs/review/iphonetips/1351143.html
# 総務省、5G基地局整備の加速化をキャリア各社に要請(2021/12/28)
# https://k-tai.watch.impress.co.jp/docs/news/1377915.html
# au「2022初売り」、「Pixel 6」や「Xperia 5 III」への機種変更で1万6500円割引／還元(2021/12/27)
# https://k-tai.watch.impress.co.jp/docs/news/1377366.html
# 楽天モバイルがパートナーと挑む、5Gで創造する新たな体験価値とは(2021/12/27)
# https://k-tai.watch.impress.co.jp/docs/topic/special/1373408.html
# 楽天モバイル「新たな試合観戦体験」の実証実験、プロジェクトメンバーが紹介(2021/12/25)
# https://k-tai.watch.impress.co.jp/docs/news/1376105.html
# オプテージら3社、集合住宅向けローカル5Gのフィールドテストを開始(2021/12/23)
# https://k-tai.watch.impress.co.jp/docs/news/1376463.html
# auオンラインショップが「Galaxy S21 5G」の手続きを一時停止、システムメンテナンスで(2021/12/22)
# https://k-tai.watch.impress.co.jp/docs/news/1376349.html
# 「日本は5Gで出遅れた」は本当か？　クアルコムのキーパーソンに聞く(2021/12/20)
# https://k-tai.watch.impress.co.jp/docs/topic/special/1373223.html
# 今日の「M-1グランプリ」をメタバースで！　本日19日14時/18時～配信スタート(2021/12/19)
# https://k-tai.watch.impress.co.jp/docs/news/1374887.html
# 連載てっぱんアプリ！by日沼 諭史「G-NetTrack Lite」は電波状況がわかるアプリ、高速通信できる場所、5Gにつながるエリアを把握したいときに(2021/12/17)
# https://k-tai.watch.impress.co.jp/docs/column/teppan/1374364.html
# KDDI、メタバースで「M-1グランプリ2021」を配信(2021/12/16)
# https://k-tai.watch.impress.co.jp/docs/news/1374875.html
# 5G時代を支えるソリューション、シスコが描くこれからの開発戦略とは(2021/12/16)
# https://k-tai.watch.impress.co.jp/docs/news/1374584.html
# 日本ではiPhone 13がiPhone 11の2倍以上の速さに――米Ooklaのスピードテスト(2021/12/16)
# https://k-tai.watch.impress.co.jp/docs/news/1374393.html
# ドコモの5G、「パケ止まり」対策の成果や5G SAの方針とは(2021/12/14)
# https://k-tai.watch.impress.co.jp/docs/news/1373774.html
# ドコモ、4G周波数の5G転用時期は「検討中」(2021/12/13)
# https://k-tai.watch.impress.co.jp/docs/news/1373827.html
# ドコモがSA方式対応スマートフォンを準備、22年夏に(2021/12/13)
# https://k-tai.watch.impress.co.jp/docs/news/1373709.html
# ドコモ、法人向けにSA方式の5Gサービス「5G SA」(2021/12/13)
# https://k-tai.watch.impress.co.jp/docs/news/1373687.html
# 連載みんなのケータイby鈴木淳也「Pixel 6 Pro」1台だけでイベントを取材してみた【Pixel 6 Pro】(2021/12/13)
# https://k-tai.watch.impress.co.jp/docs/column/minna/1373441.html
# ソフトバンクら3社、近鉄の踏切設備に遠隔状態監視システムを導入(2021/12/10)
# https://k-tai.watch.impress.co.jp/docs/news/1373002.html
# ドコモ、「home 5G HR01」でソフトウェア更新(2021/12/7)
# https://k-tai.watch.impress.co.jp/docs/news/1372286.html
# インタビュークアルコムが語る「半導体不足」その背景と影響ソニー協業の狙い、グーグル独自チップへの考えも(2021/12/3)
# https://k-tai.watch.impress.co.jp/docs/interview/1371265.html
# 「電波オークション」にソフトバンクと楽天モバイルが意見、導入には慎重な構え(2021/11/30)
# https://k-tai.watch.impress.co.jp/docs/news/1370361.html
# 産総研と大阪大学、140GHz帯ミリ波を特定方向へ向けられる反射板の開発に成功(2021/11/30)
# https://k-tai.watch.impress.co.jp/docs/news/1370079.html
# KDDIとNEXCO西日本、5G×ドローンで「高速道路の施設管理」実験(2021/11/29)
# https://k-tai.watch.impress.co.jp/docs/news/1369898.html
# KDDI、3Gサービスを22年3月31日で終了(2021/11/29)
# https://k-tai.watch.impress.co.jp/docs/news/1369833.html
# 個人向けローカル5G「NURO Wireless 5G」、22年春から(2021/11/29)
# https://k-tai.watch.impress.co.jp/docs/news/1369831.html
# ドコモとJFEエンジニアリングがDXソリューション創出・事業化の共同検討で合意(2021/11/29)
# https://k-tai.watch.impress.co.jp/docs/news/1369147.html
# クアルコムの「Snapdragon」、新たな名称「8」シリーズに(2021/11/24)
# https://k-tai.watch.impress.co.jp/docs/news/1368828.html
# ドコモら5社、8Kライブ伝送システムの実証実験に成功　医療やスポーツなどで活用見込み(2021/11/22)
# https://k-tai.watch.impress.co.jp/docs/news/1367583.html
# インタビュー京セラが「あんしんスマホ」をドコモから発売する意義とは？　京セラ／ドコモ担当者インタビュー(2021/11/22)
# https://k-tai.watch.impress.co.jp/docs/interview/1364666.html
# ソフトバンクとHonda、歩行者と車による事故低減に向けた技術検証を開始(2021/11/18)
# https://k-tai.watch.impress.co.jp/docs/news/1367166.html
# ドコモとエアバス、高高度無人機（HAPS）からの電波伝搬実験に成功(2021/11/16)
# https://k-tai.watch.impress.co.jp/docs/news/1366406.html
# 2021年度版の「周波数再編アクションプラン」、2025年度末までに約16GHz幅の帯域確保を目指す5Gや無線LANの帯域幅拡大に向けて(2021/11/15)
# https://k-tai.watch.impress.co.jp/docs/news/1366507.html
# ソフトバンクや東急、静岡県などが協力し5G SAを活用した遠隔型自動運転の実証実験(2021/11/13)
# https://k-tai.watch.impress.co.jp/docs/news/1364983.html
# 京セラとJMA Wireless、「5Gミリ波バックホールシステム」の開発を始動(2021/11/13)
# https://k-tai.watch.impress.co.jp/docs/news/1365188.html
# NTTとドコモ、5Gミリ波の反射方向を動的に制御する実験に成功(2021/11/12)
# https://k-tai.watch.impress.co.jp/docs/news/1365981.html
# 来春バルセロナで開催の「MWC」、参加受付がスタート(2021/11/12)
# https://k-tai.watch.impress.co.jp/docs/news/1365904.html
# 2021年度上期のスマホシェア、1位はアップル、2位はソニー、SIMフリースマホシェアでシャオミが初ランクイン(2021/11/12)
# https://k-tai.watch.impress.co.jp/docs/news/1365775.html
# GSMA、ミリ波普及や認知度向上図る「5G mmWave Accelerator Initiative」、ドコモなど参加(2021/11/11)
# https://k-tai.watch.impress.co.jp/docs/news/1365740.html
# 楽天モバイルと楽天ヴィッセル神戸、5GとVPSを活用した新たな観戦体験の実証実験(2021/11/11)
# https://k-tai.watch.impress.co.jp/docs/news/1365503.html
# クアルコムとNECが仮想化5Gソリューションで連携、ドコモのO-RAN構想下で開発(2021/11/11)
# https://k-tai.watch.impress.co.jp/docs/news/1365391.html
# ドコモ・KDDI・ソフトバンク・楽天の社長が「Beyond 5G」への取り組みを語る(2021/11/11)
# https://k-tai.watch.impress.co.jp/docs/news/1365347.html
# ソフトバンクとNVIDIA、完全仮想化5Gの商用化に向けた研究施設「AI-on-5G Lab.」を開設へ(2021/11/10)
# https://k-tai.watch.impress.co.jp/docs/news/1365205.html
# KDDIら4社、ローカル5Gでライブ映像をワイヤレス伝送する実証実験を開始(2021/11/9)
# https://k-tai.watch.impress.co.jp/docs/news/1364801.html
# 連載みんなのケータイby日沼諭史5Gミリ波探訪、ついに1Gbps超えを体験！【arrows 5G F-51A】(2021/11/9)
# https://k-tai.watch.impress.co.jp/docs/column/minna/1364672.html
# 楽天モバイルら3者、自律移動サービス実現に向けた自律ネットワークの研究開発を開始(2021/11/9)
# https://k-tai.watch.impress.co.jp/docs/news/1364619.html
# ドコモ、ソニー製の5Gスマホ「Xperia 5 III」を12日発売(2021/11/4)
# https://k-tai.watch.impress.co.jp/docs/news/1363789.html
# au「Xperia 5 III」を12日発売、可変望遠レンズを採用した5G対応スマートフォン(2021/11/4)
# https://k-tai.watch.impress.co.jp/docs/news/1363720.html
# 楽天モバイル、楽天市場でアップル製品を最大1万2000円割引(2021/11/4)
# https://k-tai.watch.impress.co.jp/docs/news/1363669.html
# クアルコム、5Gミリ波のまとめページを公開(2021/11/3)
# https://k-tai.watch.impress.co.jp/docs/news/1363307.html
# ドコモ、AIカメラを用いた自動配信サービス「STADIUM TUBE」を発売(2021/11/2)
# https://k-tai.watch.impress.co.jp/docs/news/1363090.html
