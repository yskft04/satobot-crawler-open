# %%
from urllib import request  # urllib.requestモジュールをインポート
from bs4 import BeautifulSoup  # BeautifulSoupクラスをインポート

url = "https://pc.watch.impress.co.jp/category/market/index.html"
response = request.urlopen(url)
soup = BeautifulSoup(response)
response.close()
#soup

## soup と実行すると、ソースコードを吐き出してくれる。
## そこから、必要な要素を考える。
links = soup.find_all("div",class_="body")
for li in links:
    #print(li)
    l = li.find("a")
    if l != None: #liに実態があれば
        url = l.get("href")
        title = li.text.replace( '\n' , '' )#何故か改行が入ってしまってる場合がある。
        print(title)
        print(url)
# Out:
# 大河原克行の「パソコン業界、東奔西走」富士通のLOOXが復活！600g台の2in1「FMV LOOX」を5月に発売～富士通40周年モデルがいきなりCESでデビュー1月4日 11:00
# https://pc.watch.impress.co.jp/docs/column/gyokai/1378165.html
# やじうまミニレビュー12.9インチiPad Proやモバイルディスプレイをアームに固定できるアタッチメントを試してみた1月4日 10:15
# https://pc.watch.impress.co.jp/docs/column/yajiuma-mini-review/1378164.html
# Dell、ゲーミングPCをゲーム配信サーバーにする「Concept Nyx」1月3日 14:01
# https://pc.watch.impress.co.jp/docs/news/event/1378122.html
# 本日みつけたお買い得品Amazon初売りセール、OWCのThunderbolt 4/USB Type-Cドックが10%オフ1月3日 12:55
# https://pc.watch.impress.co.jp/docs/news/todays_sales/1378143.html
# 本日みつけたお買い得品22cm四方で18畳対応の小型空気清浄機が15%オフの8,498円1月3日 12:38
# https://pc.watch.impress.co.jp/docs/news/todays_sales/1378140.html
# 【レビュー】7型になって大幅シェイプアップ! 「ONEXPLAYER mini」を写真でチェック
# /docs/topic/review/1374476.html
# 【コラム】 やっぱり左下にしたいWindows 11のスタートボタン。タスクバーの不要なアイコンも削除
# /docs/column/win11tec/1374983.html
# 【コラム】「Surface Pro 8」購入記。SSDを換装してお手頃価格で1TBを実現
# /docs/column/kaimono/1374217.html
# 【レビュー】コイツはカッコイイゲーミングノートだ！RTX 3060/144HzでAAA級ゲームも快適な「HP Victus 16-e0167AX」を使ってみた
# /docs/column/hothot/1374247.html
# 【レビュー】Ryzen搭載UMPC「GPD WIN Max 2021」をレビュー。高品質ゲームパッドや8コアの高い性能がウリ
# /docs/column/hothot/1373510.html
# 大河原克行の「パソコン業界、東奔西走」【新春恒例企画】2022年のPC業界はサプライチェーンに注意が必要!?(2022/1/3)
# https://pc.watch.impress.co.jp/docs/column/gyokai/1378126.html
# 日本ヒューレット・パッカード製ソフトの不具合で京大スパコンのデータ77TBが消失(2021/12/29)
# https://pc.watch.impress.co.jp/docs/news/1378005.html
# 「20世紀少年」などの浦沢直樹作品が電子版解禁。ebookjapanが試し読み増量版を提供中(2021/12/28)
# https://pc.watch.impress.co.jp/docs/news/1377700.html
# ドスパラ、秋葉原本店でHDD福袋を販売。仙台店では初売りも(2021/12/27)
# https://pc.watch.impress.co.jp/docs/news/1377570.html
# 2021年後半のトラフィック1位はTikTok。Googleを上回る(2021/12/27)
# https://pc.watch.impress.co.jp/docs/news/1377498.html
# ゲーミングPC/液晶/チェア付きで家賃4万円台からの「ゲーミング賃貸プラン」(2021/12/27)
# https://pc.watch.impress.co.jp/docs/news/1377434.html
# 今年の人気記事日本初のIBM製「ゲート型商用量子コンピュータ」が新川崎で稼働。アメリカ、ドイツに次いで世界で3番目(2021/12/25)
# https://pc.watch.impress.co.jp/docs/topic/popular/1376958.html
# 山田祥平のRe:config.sysバーチャルをリアルに近づける(2021/12/25)
# https://pc.watch.impress.co.jp/docs/column/config/1377244.html
# やじうまPC Watch劇場版「AKIRA」がYouTubeで無料公開。28日まで(2021/12/24)
# https://pc.watch.impress.co.jp/docs/news/yajiuma/1377114.html
# ASUS、Amazonギフト券などが2022名に当たるキャンペーン(2021/12/24)
# https://pc.watch.impress.co.jp/docs/news/news_flash/1377070.html
# PCのUSBに挿してBASICプログラミングできるワンボードコンピュータ「GIGA IchigoDake」(2021/12/24)
# https://pc.watch.impress.co.jp/docs/news/1377046.html
# もしスマホがマルウェアに感染したら？対処法や攻撃手口をJPCERT/CCが解説(2021/12/24)
# https://pc.watch.impress.co.jp/docs/news/1377014.html
# TP-Linkの小型無線LANルーターにOSコマンドインジェクションの脆弱性。パッチを提供中(2021/12/24)
# https://pc.watch.impress.co.jp/docs/news/1376983.html
# 福田昭のセミコン業界最前線「TSMC狂騒曲」第2楽章(2021/12/24)
# https://pc.watch.impress.co.jp/docs/column/semicon/1376547.html
# LenovoがCES 2022の現地出展をキャンセル。新型コロナの状況鑑み(2021/12/23)
# https://pc.watch.impress.co.jp/docs/news/1376811.html
# Samsung、自動最適化機能対応の「HDR10+ GAMING」採用TV/ゲーミングモニターを2022年に投入(2021/12/23)
# https://pc.watch.impress.co.jp/docs/news/1376665.html
# Dynabook、最新デバイスやDXソリューションなどを紹介するオンラインイベント開催(2021/12/22)
# https://pc.watch.impress.co.jp/docs/news/1376365.html
# ahamoやpovo 2.0の登場でMVNOが衰退(2021/12/22)
# https://pc.watch.impress.co.jp/docs/news/1376374.html
# やじうまPC Watch「三井ショッピングパークららぽーと福岡」に実物大のνガンダム立像(2021/12/22)
# https://pc.watch.impress.co.jp/docs/news/yajiuma/1376353.html
# ゲート式金属探知機をリモートで操れる脆弱性(2021/12/22)
# https://pc.watch.impress.co.jp/docs/news/1376324.html
# .bizレノボ、奥行き短めのエッジAI向けサーバー(2021/12/22)
# https://pc.watch.impress.co.jp/docs/biz/1376248.html
# 大河原克行の「パソコン業界、東奔西走」2021年の年末商戦ではなにが起こっているのか？Windows 11は10%台、Chromeは1桁台。価格転嫁の動きも(2021/12/22)
# https://pc.watch.impress.co.jp/docs/column/gyokai/1376163.html
# Huawei、Wi-Fi 6特許に関するライセンス契約でバッファローと合意(2021/12/21)
# https://pc.watch.impress.co.jp/docs/news/1376092.html
# やじうまPC WatchGoogle、新型コロナワクチン未接種の従業員を解雇へ。米CNBC報道(2021/12/21)
# https://pc.watch.impress.co.jp/docs/news/yajiuma/1376010.html
# 光回線とセットで申し込めるゲーミングPCのリースサービス。eo光が展開(2021/12/21)
# https://pc.watch.impress.co.jp/docs/news/1375948.html
# Palit、公式"萌えキャラ"の名前を募集。採用者にRTX 3060 Tiプレゼント(2021/12/20)
# https://pc.watch.impress.co.jp/docs/news/news_flash/1375703.html
# パソコン工房、2022年元日より初売りセール。福袋や特価商品など用意(2021/12/20)
# https://pc.watch.impress.co.jp/docs/news/1375613.html
# Adobe、Webブラウザ上で録音から編集まで完結できる「Project Shasta」。文字起こしテキスト編集で音声編集が可能(2021/12/20)
# https://pc.watch.impress.co.jp/docs/news/1375559.html
# アマゾンジャパンが「製品安全対策優良企業表彰」の特別賞受賞(2021/12/20)
# https://pc.watch.impress.co.jp/docs/news/1375548.html
# 子育て世帯への給付金はいつ? Yahoo! で「市区町村名 給付金」の検索が便利(2021/12/20)
# https://pc.watch.impress.co.jp/docs/news/1375537.html
# やじうまPC Watch「5G電波から身を守るペンダント」着用で被曝の可能性(2021/12/20)
# https://pc.watch.impress.co.jp/docs/news/yajiuma/1375530.html
# やじうまPC Watch「Facebook/Metaは最悪の企業」。Yahoo Finance調べ(2021/12/20)
# https://pc.watch.impress.co.jp/docs/news/yajiuma/1375456.html
# 本日みつけたお買い得品Anker製品や各社PC/スマホがお買い得! Amazon「マーケットプレイス年末年始セール」(2021/12/20)
# https://pc.watch.impress.co.jp/docs/news/todays_sales/1375469.html
# JEITA綱川会長、2022年の「カーボンニュートラル実現の鍵はデジタル」(2021/12/17)
# https://pc.watch.impress.co.jp/docs/news/1375227.html
# Meta、子どもが描いた1枚絵からアニメーションを作るAI(2021/12/17)
# https://pc.watch.impress.co.jp/docs/news/1375205.html
# LenovoのThinkPadやYogaなどのノートPCに特権昇格の脆弱性(2021/12/17)
# https://pc.watch.impress.co.jp/docs/news/1375191.html
# ソニー、ダイナミックレンジ拡大/ノイズ低減を実現する新CMOSセンサー技術(2021/12/16)
# https://pc.watch.impress.co.jp/docs/news/1374800.html
# Outlookのメールボックス障害が復旧(2021/12/16)
# https://pc.watch.impress.co.jp/docs/news/1374743.html
# IBMとSamsung、微細化FinFETと比べて85%省エネ化できる「VTFET」(2021/12/16)
# https://pc.watch.impress.co.jp/docs/news/1374737.html
# Outlookで障害。メールボックスにアクセスできず【12時56分頃復旧】(2021/12/16)
# https://pc.watch.impress.co.jp/docs/news/1374689.html
# やじうまPC WatchExcelを使った“eスポーツ大会”、17日に2021決勝戦(2021/12/15)
# https://pc.watch.impress.co.jp/docs/news/yajiuma/1374314.html
# 日本橋から宇宙への道を創り出す「TOKYO SPACE BUSINESS EXHIBITION 2021」開催(2021/12/14)
# https://pc.watch.impress.co.jp/docs/news/1374162.html
# Xiaomi、スマホのバッテリ容量を10%引き上げる技術(2021/12/14)
# https://pc.watch.impress.co.jp/docs/news/1374032.html
# PSNとLINE連携で、PS5が当たるキャンペーン(2021/12/14)
# https://pc.watch.impress.co.jp/docs/news/1373968.html
# Adobe、無料の「Creative Cloud Express」投入。デザインの心得がなくても高品質コンテンツを簡単に作成可能に(2021/12/14)
# https://pc.watch.impress.co.jp/docs/news/1373910.html
# マイクロソフトのAI技術は何が違うのか?(2021/12/14)
# https://pc.watch.impress.co.jp/docs/news/1373800.html
# AndroidスマホのゲームがまもなくWindows 10/11でプレイ可能に(2021/12/13)
# https://pc.watch.impress.co.jp/docs/news/1373581.html
# いよいよ全節終了。“エンターティナー”ウメハラがMildom Beastを3位に導く！ストリートファイターリーグ: Pro-JP 2021 第14節 Day2レポート(2021/12/10)
# https://pc.watch.impress.co.jp/docs/news/1373264.html
# Google、情報窃取や暗号通貨マイニングを行なうボットネットを阻止(2021/12/10)
# https://pc.watch.impress.co.jp/docs/news/1373143.html
# Raspberry Pi CM4を4枚、Mini-ITXに集約できるボード(2021/12/10)
# https://pc.watch.impress.co.jp/docs/news/1373069.html
