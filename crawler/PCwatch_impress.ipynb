# %%
from urllib import request  # urllib.requestモジュールをインポート
from bs4 import BeautifulSoup  # BeautifulSoupクラスをインポート

url = "https://pc.watch.impress.co.jp/"
response = request.urlopen(url)
soup = BeautifulSoup(response)
response.close()
#soup

## soup と実行すると、ソースコードを吐き出してくれる。
## そこから、必要な要素を考える。
links = soup.find_all("div",class_="body")
for li in links:
    #print(li)
    l = li.find("a")
    if l != None: #liに実態があれば
        url = l.get("href")
        title = li.text.replace( '\n' , '' )#何故か改行が入ってしまってる場合がある。
        print(title)
        print(url)
# Out:
# 2021年春 最新第11世代Core搭載ノートまとめ。1世代前の製品との性能比較も
# /docs/topic/feature/1311533.html
# 今買うならこれ! 2021年春のおすすめモニター5モデル～一般用途編
# /docs/topic/feature/1311041.html
# Webカメラが品切れでもOK? スマホをWebカメラとして使える「iVCam」を試してみた
# /docs/column/yajiuma-mini-review/1245703.html
# グリーンバックなしでも背景を消せる「XSplit VCam」を試してみた
# /docs/column/yajiuma-mini-review/1246553.html
# 無料で使える7つのビデオ会議サービスを徹底比較!
# /docs/topic/feature/1247143.html
# テレワーク初心者よ、今すぐいい椅子を買え
# /docs/column/kaimono/1245108.html
# ノイズキャンセリングヘッドセットがリビングでの仕事に最適だった
# /docs/column/kaimono/1246591.html
# テレワークをする自宅ではキーボードくらい贅沢してもいいんだぞ
# /docs/column/kaimono/1246601.html
# 1日7時間以上も向き合うディスプレイだから、2台買った話
# /docs/column/kaimono/1248102.html
# サブディスプレイが買えないなら「Duet Display」でタブレットを代用すればいいじゃない
# /docs/column/yajiuma-mini-review/1247972.html
# Discordのノイズ抑制機能を使ったら、ファンノイズも打鍵音も消え去った
# /docs/column/yajiuma-mini-review/1246853.html
# テレワーク用PCが今すぐ必要! メーカーにオススメ即納モデルを聞いてみた その1
# /docs/topic/feature/1245904.html
# テレワーク用に今すぐ必要! 即納PCを紹介 その2
# /docs/topic/feature/1246065.html
# テレワーク用に今すぐ必要! 即納PCを紹介 その3
# /docs/topic/feature/1246300.html
# PC Watchはこうやってテレワークしています
# /docs/topic/feature/1244065.html
# わが社はこうやってテレワークしています 【レノボ・ジャパン編】
# /docs/topic/feature/1247128.html
# わが社はこうやってテレワークしています【日本IBM編】
# /docs/topic/feature/1247535.html
# わが社はこうやってテレワークしています【日本マイクロソフト編】
# /docs/topic/feature/1248045.html
# わが社はこうやってテレワークしています【シャープ編】
# /docs/topic/feature/1248100.html
# わが社はこうやってテレワークしています【パナソニック編】
# /docs/topic/feature/1248849.html
# わが社はこうやってテレワークしています【アドビ編】
# /docs/topic/feature/1252820.html
# わが社はこうやってテレワークしています【セールスフォース・ドットコム編】
# /docs/topic/feature/1252831.html
# わが社はこうやってテレワークしています【富士通クライアントコンピューティング編】
# /docs/topic/feature/1253940.html
# わが社はこうやってテレワークしています【Google編】
# /docs/topic/feature/1256200.html
# わが社はこうやってテレワークしています【Amazon編】
# /docs/topic/feature/1259178.html
# 君はもう有機ELノートを見たか？ASUSが仕掛ける差別化戦略の中の1台。「Zenbook Pro 15 OLED」をレビュー
# https://pc.watch.impress.co.jp/docs/column/hothot/1378114.html
# スマホの拡張ディスプレイとしてコモディティ化するスマートウォッチ/バンド
# https://pc.watch.impress.co.jp/docs/column/config/1378052.html
# 結局、M1 Pro/Max版MacBook Proで“作業”が速くなるのか？動画編集者が試したら驚きの結果に
# https://pc.watch.impress.co.jp/docs/topic/feature/1378023.html
# 在宅勤務・テレワークのお悩み解決はこちら！
# /backno/lifeathome/
# イベントCES2022大河原克行の「パソコン業界、東奔西走」富士通のLOOXが復活！600g台の2in1「FMV LOOX」を5月に発売～富士通40周年モデルがいきなりCESでデビュー 11:00
# /docs/column/gyokai/1378165.html
# 半導体/周辺機器アクセサリその他やじうまミニレビュー12.9インチiPad Proやモバイルディスプレイをアームに固定できるアタッチメントを試してみた 10:15
# /docs/column/yajiuma-mini-review/1378164.html
# PC Watch 25周年企画
# /pcw25th/
# Capcom Cup 2018覇者のガチくんがお届けするストリートファイターV攻略企画「ガチくんに!」、毎週金曜21時より生配信!
# /backno/fixed/impress_esports/gachikun/
# 中古品専門ニュースサイト「中古PC Hotline!」PCやタブレットなどの中古品お買い得情報をまとめてチェック！
# https://akiba-pc.watch.impress.co.jp/topics/usedpc_hotline/
# Intelプロセッサー・ナンバー(デスクトップ)
# https://pc.watch.impress.co.jp/docs/topic/spec/intel_cpu_spec.html
# Intelプロセッサー・ナンバー(ノート)
# https://pc.watch.impress.co.jp/docs/topic/spec/intel_mobile_spec.html
# AMDモデルナンバー
# https://pc.watch.impress.co.jp/docs/topic/spec/amd_cpu_spec.html
# 【レビュー】7型になって大幅シェイプアップ! 「ONEXPLAYER mini」を写真でチェック
# /docs/topic/review/1374476.html
# 【コラム】 やっぱり左下にしたいWindows 11のスタートボタン。タスクバーの不要なアイコンも削除
# /docs/column/win11tec/1374983.html
# 【コラム】「Surface Pro 8」購入記。SSDを換装してお手頃価格で1TBを実現
# /docs/column/kaimono/1374217.html
# 【レビュー】コイツはカッコイイゲーミングノートだ！RTX 3060/144HzでAAA級ゲームも快適な「HP Victus 16-e0167AX」を使ってみた
# /docs/column/hothot/1374247.html
# 【レビュー】Ryzen搭載UMPC「GPD WIN Max 2021」をレビュー。高品質ゲームパッドや8コアの高い性能がウリ
# /docs/column/hothot/1373510.html
# パソコン/タブレット/スマートフォンノートパソコンASUSHothotレビュー君はもう有機ELノートを見たか？ASUSが仕掛ける差別化戦略の中の1台。「Zenbook Pro 15 OLED」をレビュー 06:22
# /docs/news/1378087.html
# 半導体/周辺機器ペンタブレットその他XP-PEN、高性能ペン付属の無線/有線ペンタブ。Amazonで15%オフ中 12:41
# /docs/news/1378085.html
# パソコン/タブレット/スマートフォンノートパソコンMacBook結局、M1 Pro/Max版MacBook Proで“作業”が速くなるのか？動画編集者が試したら驚きの結果に 06:20
# /docs/topic/feature/1378023.html
# 半導体/周辺機器その他【最新版】便利に使えるUSB Type-C/Thunderboltドッキングステーションおすすめ10選 06:41
# /docs/topic/feature/1378034.html
# ソフトウェア/アプリWindows新バージョンWindows 11便利テクWindows 11でファイルの関連付けができない！そんな時に役立つアプリのリセット 06:31
# /docs/column/win11tec/1378029.html
# 大河原克行の「パソコン業界、東奔西走」富士通のLOOXが復活！600g台の2in1「FMV LOOX」を5月に発売～富士通40周年モデルがいきなりCESでデビュー2022年1月4日 11:00
# https://pc.watch.impress.co.jp/docs/column/gyokai/1378165.html
# やじうまミニレビュー12.9インチiPad Proやモバイルディスプレイをアームに固定できるアタッチメントを試してみた2022年1月4日 10:15
# https://pc.watch.impress.co.jp/docs/column/yajiuma-mini-review/1378164.html
# Hothotレビュー君はもう有機ELノートを見たか？ASUSが仕掛ける差別化戦略の中の1台。「Zenbook Pro 15 OLED」をレビュー2022年1月3日 06:22
# https://pc.watch.impress.co.jp/docs/column/hothot/1378114.html
# インプレスeスポーツ部女子レトロゲーム班by黒田 瑞貴黒田瑞貴、「ドラゴンスレイヤー英雄伝説はいつも想像の少し上をかましてくる」2022年1月1日 08:00
# https://pc.watch.impress.co.jp/docs/column/retro-game-joshi/1378054.html
# 山田祥平のRe:config.sysスマホの拡張ディスプレイとしてコモディティ化するスマートウォッチ/バンド2022年1月1日 06:25
# https://pc.watch.impress.co.jp/docs/column/config/1378052.html
# Windows 11便利テクWindows 11でファイルの関連付けができない！そんな時に役立つアプリのリセット2021年12月31日 06:31
# https://pc.watch.impress.co.jp/docs/column/win11tec/1378029.html
# 西川和久の不定期コラム2021年を振り返る。macOS Monterey/Windows 11ともに目玉機能が先送りになるめずらしい年2021年12月29日 06:40
# https://pc.watch.impress.co.jp/docs/column/nishikawa/1377644.html
# 笠原一輝のユビキタス情報局第12世代CoreのDRM問題は解決の方向へ。Intel開発者が語るAlder Lakeがゲームに魅力的な理由とは2021年12月29日 06:21
# https://pc.watch.impress.co.jp/docs/column/ubiq/1377896.html
# Mac InfoMacを正しい方法でお掃除！ 話題のApple純正布「ポリッシングクロス」も使ってみた2021年12月24日 09:48
# https://pc.watch.impress.co.jp/docs/column/macinfo/1376896.html
# 福田昭のセミコン業界最前線「TSMC狂騒曲」第2楽章2021年12月24日 06:16
# https://pc.watch.impress.co.jp/docs/column/semicon/1376547.html
